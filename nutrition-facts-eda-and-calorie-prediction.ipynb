# %% [markdown]
# # **Introduction**

# %% [markdown]
# ### **☕️🍩 Project Overview**
#
# This project aims to analyze the nutritional values of items on the Starbucks menu and predict their calorie content using various machine learning models. The project includes comprehensive Exploratory Data Analysis (EDA), investigation of relationships between nutritional values and product types, and the implementation of several regression algorithms for modeling.
#
# ### **🎯 Main Objectives:**
# #### **📊 Exploratory Data Analysis (EDA):**
# Analyze the nutritional values (calories, fat, carbohydrates, fiber, protein) and product types of Starbucks menu items.
# #### **🧹 Data Preprocessing:**
# Apply necessary transformations and cleaning steps to prepare the dataset for machine learning models.
# #### **🤖 Modeling:**
# Predict the calorie content of products using different regression models (Linear Regression, Random Forest, Gradient Boosting, K-Nearest Neighbors, Support Vector Regression, LightGBM, CatBoost, MLP) and compare their performances.
# #### **📈 Visualization:**
# Present key findings and model results with various visualizations.
#
# #### **🗂️ Dataset Features:**
#
# * **item:**	The name of the food item.
# * **calories:**	The amount of calories in the food item.
# * **fat:**	The quantity of fat in grams present in the food item.
# * **carb:**	The amount of carbohydrates in grams found in the food item.
# * **fiber:**	The quantity of dietary fiber in grams in the food item.
# * **protein:**	The amount of protein in grams contained in the food item.
# * **type:**	The category or type of food item (bakery, bistro box, hot breakfast, parfait, petite, salad, or sandwich).

# %% [markdown]
# # **Import And Install Necessary Libraries**

# %%
# !pip install lightgbm
# !pip install catboost

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import accuracy_score, r2_score, mean_squared_error
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # **Load the Dataset**

# %%
df = pd.read_csv('/kaggle/input/starbucks-nutrition/starbucks.csv')

# %%
df
# Out:
#     Unnamed: 0                                   item  calories   fat  carb  \
# 0            1                           8-Grain Roll       350   8.0    67
# 1            2                      Apple Bran Muffin       350   9.0    64
# 2            3                          Apple Fritter       420  20.0    59
# 3            4                        Banana Nut Loaf       490  19.0    75
# 4            5            Birthday Cake Mini Doughnut       130   6.0    17
# ..         ...                                    ...       ...   ...   ...
# 72          73        Tarragon Chicken Salad Sandwich       420  13.0    46
# 73          74                Turkey & Swiss Sandwich       390  13.0    36
# 74          75             Greek Yogurt Honey Parfait       300  12.0    44
# 75          76         Peach Raspberry Yogurt Parfait       300   4.0    57
# 76          77  Strawberry & Blueberry Yogurt Parfait       300   3.5    60
#
#     fiber  protein      type
# 0       5       10    bakery
# 1       7        6    bakery
# 2       0        5    bakery
# 3       4        7    bakery
# 4       0        0    bakery
# ..    ...      ...       ...
# 72      6       32  sandwich
# 73      2       34  sandwich
# 74      0        8   parfait
# 75      3       10   parfait
# 76      3        7   parfait
#
# [77 rows x 8 columns]

# %% [markdown]
# # **Understand And Organize the Dataset**

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df
# Out:
#                                      item  calories   fat  carb  fiber  \
# 0                            8-Grain Roll       350   8.0    67      5
# 1                       Apple Bran Muffin       350   9.0    64      7
# 2                           Apple Fritter       420  20.0    59      0
# 3                         Banana Nut Loaf       490  19.0    75      4
# 4             Birthday Cake Mini Doughnut       130   6.0    17      0
# ..                                    ...       ...   ...   ...    ...
# 72        Tarragon Chicken Salad Sandwich       420  13.0    46      6
# 73                Turkey & Swiss Sandwich       390  13.0    36      2
# 74             Greek Yogurt Honey Parfait       300  12.0    44      0
# 75         Peach Raspberry Yogurt Parfait       300   4.0    57      3
# 76  Strawberry & Blueberry Yogurt Parfait       300   3.5    60      3
#
#     protein      type
# 0        10    bakery
# 1         6    bakery
# 2         5    bakery
# 3         7    bakery
# 4         0    bakery
# ..      ...       ...
# 72       32  sandwich
# 73       34  sandwich
# 74        8   parfait
# 75       10   parfait
# 76        7   parfait
#
# [77 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   item      77 non-null     object
#  1   calories  77 non-null     int64
#  2   fat       77 non-null     float64
#  3   carb      77 non-null     int64
#  4   fiber     77 non-null     int64
#  5   protein   77 non-null     int64
#  6   type      77 non-null     object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 4.3+ KB

# %%
df.isnull().sum()
# Out:
# item        0
# calories    0
# fat         0
# carb        0
# fiber       0
# protein     0
# type        0
# dtype: int64

# %%
df['type'].unique()
# Out:
# array(['bakery', 'bistro box', 'petite', 'hot breakfast', 'salad',
#        'sandwich', 'parfait'], dtype=object)

# %%
df.groupby('type').count()
# Out:
#                item  calories  fat  carb  fiber  protein
# type
# bakery           41        41   41    41     41       41
# bistro box        8         8    8     8      8        8
# hot breakfast     8         8    8     8      8        8
# parfait           3         3    3     3      3        3
# petite            9         9    9     9      9        9
# salad             1         1    1     1      1        1
# sandwich          7         7    7     7      7        7

# %%
df.groupby('type')['item'].count()
# Out:
# type
# bakery           41
# bistro box        8
# hot breakfast     8
# parfait           3
# petite            9
# salad             1
# sandwich          7
# Name: item, dtype: int64

# %% [markdown]
# ## **Visualization of How Many Items Are of Which Type**

# %%
type_counts = df.groupby('type')['item'].count().reset_index()
plt.figure(figsize=(8, 5))
sns.barplot(x='type', y='item', data=type_counts, palette='rocket');

# %% [markdown]
# ## **Visualization of the Average Calories Value of Each Type Group**

# %%
sns.barplot(x='type', y='calories', data=df, palette='rocket');

# %% [markdown]
# ## **Histograms of Numerical Variables**

# %%
df.hist(figsize=(10, 8), bins=10, color='c', edgecolor='k')
plt.suptitle("Histograms of Numerical Variables")
plt.show()

# %% [markdown]
# ## **Visualization of Fat and Protein Distribution**

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x="fat", y="protein", hue="calories", size="calories", data=df, palette="coolwarm", sizes=(20, 200))
plt.title("Fat and Protein Distribution")
plt.show()

# %% [markdown]
# ## **Visualization Average Nutritional Values ​​by Food Types**

# %%
plt.figure(figsize=(12,6))
df.groupby('type')[['calories', 'fat', 'carb', 'protein']].mean().plot(kind='bar')
plt.title('Average Nutritional Values ​​by Food Types')
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Visualization of Relationships Between Pairs of Variables in Dataset**

# %%
sns.pairplot(df, hue='type');

# %% [markdown]
# ## **Dummying the 'type' Variable, Which is a Categorical Variable**

# %%
df = pd.get_dummies(df,columns=['type'], drop_first=True)

# %%
df.head()
# Out:
#                           item  calories   fat  carb  fiber  protein  \
# 0                 8-Grain Roll       350   8.0    67      5       10
# 1            Apple Bran Muffin       350   9.0    64      7        6
# 2                Apple Fritter       420  20.0    59      0        5
# 3              Banana Nut Loaf       490  19.0    75      4        7
# 4  Birthday Cake Mini Doughnut       130   6.0    17      0        0
#
#    type_bistro box  type_hot breakfast  type_parfait  type_petite  type_salad  \
# 0            False               False         False        False       False
# 1            False               False         False        False       False
# 2            False               False         False        False       False
# 3            False               False         False        False       False
# 4            False               False         False        False       False
#
#    type_sandwich
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   item                77 non-null     object
#  1   calories            77 non-null     int64
#  2   fat                 77 non-null     float64
#  3   carb                77 non-null     int64
#  4   fiber               77 non-null     int64
#  5   protein             77 non-null     int64
#  6   type_bistro box     77 non-null     bool
#  7   type_hot breakfast  77 non-null     bool
#  8   type_parfait        77 non-null     bool
#  9   type_petite         77 non-null     bool
#  10  type_salad          77 non-null     bool
#  11  type_sandwich       77 non-null     bool
# dtypes: bool(6), float64(1), int64(4), object(1)
# memory usage: 4.2+ KB

# %%
df.describe()
# Out:
#          calories        fat       carb      fiber    protein
# count   77.000000  77.000000  77.000000  77.000000  77.000000
# mean   338.831169  13.766234  44.870130   2.220779   9.480519
# std    105.368701   7.095488  16.551634   2.112764   8.079556
# min     80.000000   0.000000  16.000000   0.000000   0.000000
# 25%    300.000000   9.000000  31.000000   0.000000   5.000000
# 50%    350.000000  13.000000  45.000000   2.000000   7.000000
# 75%    420.000000  18.000000  59.000000   4.000000  15.000000
# max    500.000000  28.000000  80.000000   7.000000  34.000000

# %%
df = df.drop('item', axis=1)

# %%
df.shape
# Out:
# (77, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   calories            77 non-null     int64
#  1   fat                 77 non-null     float64
#  2   carb                77 non-null     int64
#  3   fiber               77 non-null     int64
#  4   protein             77 non-null     int64
#  5   type_bistro box     77 non-null     bool
#  6   type_hot breakfast  77 non-null     bool
#  7   type_parfait        77 non-null     bool
#  8   type_petite         77 non-null     bool
#  9   type_salad          77 non-null     bool
#  10  type_sandwich       77 non-null     bool
# dtypes: bool(6), float64(1), int64(4)
# memory usage: 3.6 KB

# %%
df
# Out:
#     calories   fat  carb  fiber  protein  type_bistro box  type_hot breakfast  \
# 0        350   8.0    67      5       10            False               False
# 1        350   9.0    64      7        6            False               False
# 2        420  20.0    59      0        5            False               False
# 3        490  19.0    75      4        7            False               False
# 4        130   6.0    17      0        0            False               False
# ..       ...   ...   ...    ...      ...              ...                 ...
# 72       420  13.0    46      6       32            False               False
# 73       390  13.0    36      2       34            False               False
# 74       300  12.0    44      0        8            False               False
# 75       300   4.0    57      3       10            False               False
# 76       300   3.5    60      3        7            False               False
#
#     type_parfait  type_petite  type_salad  type_sandwich
# 0          False        False       False          False
# 1          False        False       False          False
# 2          False        False       False          False
# 3          False        False       False          False
# 4          False        False       False          False
# ..           ...          ...         ...            ...
# 72         False        False       False           True
# 73         False        False       False           True
# 74          True        False       False          False
# 75          True        False       False          False
# 76          True        False       False          False
#
# [77 rows x 11 columns]

# %% [markdown]
# # **Models Building**

# %%
x = df.drop('calories',axis=1)
y = df[['calories']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.80, random_state=42)

# %%
x_test.shape
# Out:
# (16, 10)

# %% [markdown]
# ## **Random Forest Regressor Model**

# %%
rf = RandomForestRegressor(n_estimators=600, random_state=42)
model_rf = rf.fit(x_train, y_train)
# Out:
# <ipython-input-29-7136849b0adf>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model_rf = rf.fit(x_train, y_train)

# %%
model_rf.score(x_test, y_test)
# Out:
# 0.9328518833259388

# %%
y_pred = model_rf.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
# Out:
# Mean Squared Error: 1024.7432118055556
# R² Score: 0.9328518833259388

# %% [markdown]
# ## **Linear Regression Model**

# %%
lr = LinearRegression()
model_lr = lr.fit(x_train, y_train)

# %% [markdown]
# linear Model

# %%
model_lr.score(x_test, y_test)
# Out:
# 0.9930687931839743

# %%
y_pred = model_lr.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
# Out:
# Mean Squared Error: 105.77671401894098
# R² Score: 0.9930687931839743

# %% [markdown]
# ## **GBM (Gradient Boosting Regressor) Model**

# %%
gbm = GradientBoostingRegressor(random_state=42, learning_rate=0.5, max_depth=4, n_estimators=400, subsample=0.5)

# %%
model_gbm = gbm.fit(x_train, y_train)
model_gbm.score(x_test, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9738130503937129

# %% [markdown]
# ## **K Neighbors Regressor Model**

# %%
knn = KNeighborsRegressor(n_neighbors=1)
model_knn = knn.fit(x_train, y_train)
model_knn.score(x_test, y_test)
# Out:
# 0.9561789700010238

# %%
y_pred = model_knn.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
# Out:
# Mean Squared Error: 668.75
# R² Score: 0.9561789700010238

# %% [markdown]
# ## **SVR (Support Vector Regression) Model**

# %%
svr = SVR(kernel="linear", C=6)
svr_model = svr.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
svr_model.score(x_test, y_test)
# Out:
# 0.9943433686184033

# %%
y_pred = svr_model.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
# Out:
# Mean Squared Error: 86.32549797508611
# R² Score: 0.9943433686184033

# %% [markdown]
# ## **LGBM (Light Gradient Boosting Machine) Model**

# %% [markdown]
# ***To ignore warnings, let's add the verbose parameter and set it equal to -1.***

# %%
lgbm = LGBMRegressor(learning_rate=0.1, n_estimators=500, max_depth=4, verbose=-1)
lgbm_model = lgbm.fit(x_train, y_train)
lgbm_model.score(x_test, y_test)
# Out:
# 0.8741455407843808

# %%
y_pred = lgbm_model.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
# Out:
# Mean Squared Error: 1920.657036185864
# R² Score: 0.8741455407843808

# %% [markdown]
# ## **CatBoost Regressor Model**

# %% [markdown]
# ***To ignore warnings, let's add the verbose parameter and set it equal to 0. CatBoost does not accept -1.***

# %%
catb = CatBoostRegressor(iterations=200, learning_rate=0.1, depth=3, verbose=0)
model_catb = catb.fit(x_train, y_train)

# %%
model_catb.score(x_test, y_test)
# Out:
# 0.966404526419992

# %%
y_pred = model_catb.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
# Out:
# Mean Squared Error: 512.6984225874031
# R² Score: 0.966404526419992

# %% [markdown]
# ## **MLP (Multi-Layer Perceptron) Regressor**

# %%
mlp = MLPRegressor(learning_rate_init=0.1, max_iter=100, random_state=42, hidden_layer_sizes=(100, 50))
mlp_model = mlp.fit(x_train, y_train)
mlp_model.score(x_test, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1623: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9961179586398871

# %%
y_pred = mlp_model.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
# Out:
# Mean Squared Error: 59.243590569098934
# R² Score: 0.9961179586398871

# %% [markdown]
# # **Correlation Heatmap**

# %% [markdown]
# ***Correlation heat map according to the highest score, that is, MLP (Multi-Layer Perceptron) Regressor model:***

# %%
df.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(df.corr(), annot=True);
plt.title('Correlation Heatmap');

# %% [markdown]
# # **Visualization of Actual And Predicted Values ​In the Test Dataset**

# %% [markdown]
# ***According to the MLP (Multi-Layer Perceptron) Regressor model***

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend(prop=dict(size=14))
plt.title('Actual vs Predicted Calories of Test Dataset')
plt.xlabel('Data Points')
plt.ylabel('Calories')
plt.show()

# %% [markdown]
# # **Visualization of Actual And Predicted Values ​In the Full Dataset**

# %% [markdown]
# ***According to the MLP (Multi-Layer Perceptron) Regressor model***

# %%
y_pred_all = mlp_model.predict(x)

plt.figure(figsize=(10, 6))
plt.plot(y.values, label='Actual')
plt.plot(y_pred_all, label='Predicted')
plt.legend(prop=dict(size=14))
plt.title('Actual vs Predicted Calories of Full Dataset')
plt.xlabel('Data Points')
plt.ylabel('Calories')
plt.show()

# %% [markdown]
# # **Conclusion**
# In this project, we analyzed the nutritional values of Starbucks menu items and predicted their calorie content using various machine learning models. After thorough data cleaning and visualization, we applied several regression algorithms—including Linear Regression, Random Forest, Gradient Boosting, LightGBM, CatBoost, and MLP.
# Among all models, the MLP Regressor achieved the highest accuracy in calorie prediction. Our results show that machine learning can effectively estimate nutritional values, supporting healthier choices and data-driven decisions in the food sector.
